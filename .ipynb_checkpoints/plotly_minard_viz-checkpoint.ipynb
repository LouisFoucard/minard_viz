# %%
from plotly.offline import init_notebook_mode, iplot
from IPython.display import display, HTML
import pandas as pd
import plotly.graph_objs as go

# %%
df = pd.DataFrame()
df = df.from_csv('data_edited.csv', index_col=None)
division_1 = df[df.DIVISION == 'I']
division_2 = df[df.DIVISION == 'II']
division_2 = df[df.DIVISION == 'III']
division_1
# Out:
#     LONT  TEMP  DAYS      DATE    LONP    LATP  SURVIV    DIREC DIVISION
# 0   37.6   NaN     6     Oct 3  24.050  54.600  340000  Advance        I
# 1   36.0   NaN     6     Oct 4  24.800  54.820  340000  Advance        I
# 2   33.2   NaN     6     Oct 5  25.800  54.600  340000  Advance        I
# 3   32.0   NaN     6     Oct 6  26.750  54.850  320000  Advance        I
# 4   29.2   NaN     6     Oct 7  27.499  55.050  300000  Advance        I
# 5   28.5   NaN     6     Oct 8  28.150  55.200  280000  Advance        I
# 6   27.2   NaN     6     Oct 9  29.000  55.300  240000  Advance        I
# 7   26.7   NaN     6    Oct 10  29.550  55.360  210000  Advance        I
# 8   25.3   NaN     6    Oct 11  30.290  55.405  180000  Advance        I
# 9   25.3   NaN     6    Oct 12  30.500  55.405  175000  Advance        I
# 10  25.3   NaN     6    Oct 13  32.200  54.850  145000  Advance        I
# 11  25.3   NaN     6    Oct 14  33.750  55.400  140000  Advance        I
# 12  25.3   NaN     6    Oct 15  35.050  56.550  127100  Advance        I
# 13  25.3   NaN     6    Oct 16  36.150  56.380  100000  Advance        I
# 14  25.3   NaN     6    Oct 17  37.600  57.100  100000  Advance        I
# 15  25.3     0     6    Oct 18  37.750  56.850  100000  Retreat        I
# 16  25.3     0     6    Oct 18  37.600  56.800   98000  Retreat        I
# 17  25.3     0     6    Oct 18  37.500  55.800   97000  Retreat        I
# 18  25.3     0     6    Oct 24  37.280  55.680   96000  Retreat        I
# 19  25.3    -3     6    Oct 24  35.800  56.050   87000  Retreat        I
# 20  25.3    -6     6    Oct 24  34.750  55.570   55000  Retreat        I
# 21  25.3    -9    16     Nov 9  33.750  55.000   37000  Retreat        I
# 22  25.3   -21     5    Nov 14  32.450  54.550   24000  Retreat        I
# 23  25.3   -16     5    Nov 19  30.900  54.250   20000  Retreat        I
# 24  25.3   -11    10    Nov 24  29.800  53.750   20000  Retreat        I
# 25  25.3   -18    10    Nov 26  29.100  53.540   20000  Retreat        I
# 26  25.3   -20     4    Nov 28  28.900  53.560   20000  Retreat        I
# 27  25.3   -24     3     Dec 1  27.950  54.120   20000  Retreat        I
# 28  25.3   -30     5     Dec 6  27.410  53.820   12000  Retreat        I
# 29  25.3   -29   NaN     Dec 6  26.900  53.970   14000  Retreat        I
# 30  25.3   -26     1     Dec 7  25.600  54.050    8000  Retreat        I
# 31  25.3   NaN   NaN    Dec 15  25.070  54.030    4000  Retreat        I
# 32  25.3   NaN   NaN    Dec 16  24.580  54.000    4000  Retreat        I
# 33  25.3   NaN   NaN    Dec 17  24.210  53.990    4000  Retreat        I

# %%
division_1_segments_LONP = [division_1.LONP.values[i:i+2] 
                       for i in range(division_1.LONP.values.shape[0])]

division_1_segments_LATP = [division_1.LATP.values[i:i+2] 
                       for i in range(division_1.LATP.values.shape[0])]

division_1_segments_LONP_init = [[None, None] 
                       for i in range(division_1.LONP.values.shape[0])]

division_1_segments_LATP_init = [[None, None] 
                       for i in range(division_1.LATP.values.shape[0])]

division_1_segments_TEMPS = [division_1.TEMP.values[i:i+2] 
                       for i in range(division_1.LATP.values.shape[0])]

# %%
frames = [{'data': [go.Scatter({'x': lonp if n < f + 1 else [None, None],
                                'y': latp if n < f + 1 else [None, None],
                                'mode': 'line+marker',
                                'line': {'width': surv / 10000.0 if n < f else 0,
                                         'color': 'BurlyWood' if direction == 'Advance' else 'black'},
                                'marker': {'size': 1.0 * surv / 10000.0 if n < f else 0},
                                'name': 'troops: {}'.format(surv),
                                'textsrc': 'test'})
                    for n, (lonp, latp, surv, direction) in enumerate(zip(division_1_segments_LONP,
                                                                          division_1_segments_LATP,
                                                                          division_1.SURVIV,
                                                                          division_1.DIREC))] \
                   + [go.Scatter({'x': lonp if n < f + 1 else [None, None],
                                  'y': temp if n < f + 1 else [None, None],
                                  'mode': 'line+marker',
                                  'line': {'width': 1, 'color': 'black'},
                                  'marker': {'size': 0.001},
                                  'name': 'temp :{}'.format(temp[0]),
                                  'textsrc': 'test',
                                  'xaxis': 'x',
                                  'yaxis': 'y2'})
                      for n, (lonp, temp) in enumerate(zip(division_1_segments_LONP,
                                                           division_1_segments_TEMPS))],
          'layout': {'title': '{}'.format(division_1.DATE.values[f])}} for f in range(34)]

# %%
background_image_url = "https://raw.githubusercontent.com/LouisFoucard/minard_viz/master/Minard's_Map.png"

init_notebook_mode(connected=True)

data = [go.Scatter({'x': [None, None],
                    'y': [None, None],
                    'mode': 'line+marker',
                    'line': {'width': 0,
                             'color': 'BurlyWood' if direction == 'Advance' else 'black'},
                    'name': 'troops:{}'.format(surv),
                    'marker': {'size': 0}})
        for lonp, latp, surv, direction in zip(division_1_segments_LONP,
                                               division_1_segments_LATP,
                                               division_1.SURVIV,
                                               division_1.DIREC)] + [go.Scatter({'x': [None, None],
                                                                                 'y': [None, None],
                                                                                 'mode': 'line+marker',
                                                                                 'line': {'width': 1},
                                                                                 'name': 'temp :{}'.format(temp),
                                                                                 'textsrc': 'test',
                                                                                 'xaxis': 'x',
                                                                                 'yaxis': 'y2'})
                                                                     for n, (lonp, temp) in
                                                                     enumerate(zip(division_1_segments_LONP,
                                                                                   division_1_segments_TEMPS))]

layout = {'xaxis': {'range': [23.1, 38.4], 'autorange': False},
          'yaxis': {'range': [51.25, 58.25], 'autorange': False, 'domain': [0.3, 1]},
          'title': 'Start Title', 'showlegend': False,
          'images': [dict(source=background_image_url,
                          xref="x",
                          yref="y",
                          x=23.2,
                          y=58.25,
                          sizex=15,
                          sizey=7,
                          sizing="stretch",
                          opacity=1,
                          layer="below")],
          'yaxis2': {'domain': [0, 0.25]},
          'autosize': False,
          'width': 1000,
          'height': 600}

frames += [{'layout': {'title': 'End Title',
                       'updatemenus': [{'type': 'buttons',
                                        'buttons': [{'label': 'Play',
                                                     'method': 'animate',
                                                     'args': [None]}]}],
                       'showlegend': False}}]

fig = go.Figure(data=data, layout=layout, frames=frames)
iplot(fig, filename='Minard viz')
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>
# <div id="673a2304-6da1-4cfb-a818-c9c49b239d0f" style="height: 600px; width: 1000px;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";
#         Plotly.plot(
#             '673a2304-6da1-4cfb-a818-c9c49b239d0f',
#             [{"name": "troops:340000", "marker": {"size": 0}, "mode": "line+marker", "y": [null, null], "x": [null, null], "line": {"color": "BurlyWood", "width": 0}, "type": "scatter"}, {"name": "troops:340000", "marker": {"size": 0}, "mode": "line+marker", "y": [null, null], "x": [null, null], "line": {"color": "BurlyWood", "width": 0}, "type": "scatter"}, {"name": "troops:340000", "marker": {"size": 0}, "mode": "line+marker", "y": [null, null], "x": [null, null], "line": {"color": "BurlyWood", "width": 0}, "type": "scatter"}, {"name": "troops:320000", "marker": {"size": 0}, "mode": "line+marker", "y": [null, null], "x": [null, null], "line": {"color": "BurlyWood", "width": 0}, "type": "scatter"}, {"name": "troops:300000", "marker": {"size": 0}, "mode": "line+marker", "y": [null, null], "x": [null, null], "line": {"color": "BurlyWood", "width": 0}, "type": "scatter"}, {"name": "troops:280000", "marker": {"size": 0}, "mode": "line+marker", "y": [null, null], "x": [null, null], "line": {"color": "BurlyWood", "width": 0}, "type": "scatter"}, {"name": "troops:240000", "marker": {"size": 0}, "mode": "line+marker", "y": [null, null], "x": [null, null], "line": {"color": "BurlyWood", "width": 0}, "type": "scatter"}, {"name": "troops:210000", "marker": {"size": 0}, "mode": "line+marker", "y": [null, null], "x": [null, null], "line": {"color": "BurlyWood", "width": 0}, "type": "scatter"}, {"name": "troops:180000", "marker": {"size": 0}, "mode": "line+marker", "y": [null, null], "x": [null, null], "line": {"color": "BurlyWood", "width": 0}, "type": "scatter"}, {"name": "troops:175000", "marker": {"size": 0}, "mode": "line+marker", "y": [null, null], "x": [null, null], "line": {"color": "BurlyWood", "width": 0}, "type": "scatter"}, {"name": "troops:145000", "marker": {"size": 0}, "mode": "line+marker", "y": [null, null], "x": [null, null], "line": {"color": "BurlyWood", "width": 0}, "type": "scatter"}, {"name": "troops:140000", "marker": {"size": 0}, "mode": "line+marker", "y": [null, null], "x": [null, null], "line": {"color": "BurlyWood", "width": 0}, "type": "scatter"}, {"name": "troops:127100", "marker": {"size": 0}, "mode": "line+marker", "y": [null, null], "x": [null, null], "line": {"color": "BurlyWood", "width": 0}, "type": "scatter"}, {"name": "troops:100000", "marker": {"size": 0}, "mode": "line+marker", "y": [null, null], "x": [null, null], "line": {"color": "BurlyWood", "width": 0}, "type": "scatter"}, {"name": "troops:100000", "marker": {"size": 0}, "mode": "line+marker", "y": [null, null], "x": [null, null], "line": {"color": "BurlyWood", "width": 0}, "type": "scatter"}, {"name": "troops:100000", "marker": {"size": 0}, "mode": "line+marker", "y": [null, null], "x": [null, null], "line": {"color": "black", "width": 0}, "type": "scatter"}, {"name": "troops:98000", "marker": {"size": 0}, "mode": "line+marker", "y": [null, null], "x": [null, null], "line": {"color": "black", "width": 0}, "type": "scatter"}, {"name": "troops:97000", "marker": {"size": 0}, "mode": "line+marker", "y": [null, null], "x": [null, null], "line": {"color": "black", "width": 0}, "type": "scatter"}, {"name": "troops:96000", "marker": {"size": 0}, "mode": "line+marker", "y": [null, null], "x": [null, null], "line": {"color": "black", "width": 0}, "type": "scatter"}, {"name": "troops:87000", "marker": {"size": 0}, "mode": "line+marker", "y": [null, null], "x": [null, null], "line": {"color": "black", "width": 0}, "type": "scatter"}, {"name": "troops:55000", "marker": {"size": 0}, "mode": "line+marker", "y": [null, null], "x": [null, null], "line": {"color": "black", "width": 0}, "type": "scatter"}, {"name": "troops:37000", "marker": {"size": 0}, "mode": "line+marker", "y": [null, null], "x": [null, null], "line": {"color": "black", "width": 0}, "type": "scatter"}, {"name": "troops:24000", "marker": {"size": 0}, "mode": "line+marker", "y": [null, null], "x": [null, null], "line": {"color": "black", "width": 0}, "type": "scatter"}, {"name": "troops:20000", ...

# %%
background_image_url = "https://raw.githubusercontent.com/LouisFoucard/minard_viz/master/Minard's_Map.png"

init_notebook_mode(connected=True)

figure = {'data': [go.Scatter({'x': lonp, 
                    'y': latp, 
                    'mode': 'line+marker', 
                    'line': {'width': 0,
                             'color':'BurlyWood' if direction=='Advance' else 'black'},
                   'name': 'surviv:{}'.format(surv),
                    'marker': {'size': 0}}) 
                   for lonp, latp, surv, direction in zip(division_1_segments_LONP, 
                                               division_1_segments_LATP,
                                               division_1.SURVIV,
                                               division_1.DIREC)],
          'layout': {'xaxis': {'range': [23.1, 38.4], 'autorange': False},
                     'yaxis': {'range': [51.25, 58.25], 'autorange': False},
                     'title': 'Start Title', 'showlegend': False,
                    'images': [dict(source= background_image_url, 
                                    xref= "x",
                                    yref= "y",
                                    x= 23.2,
                                    y= 58.25,
                                    sizex= 15,
                                    sizey= 7,
                                    sizing= "stretch",
                                    opacity= 1,
                                    layer= "below")]},
                    'frames': frames+[{'data': [{'x': lonp, 
                                          'y': latp,
                                          'mode': 'line+marker', 
                                          'line': {'width': surv/8000.0,
                                                  'color':'BurlyWood' if direction=='Advance' else 'black'},
                                         'marker': {'size': 1.2*surv/10000.0},
                                         'name':'surviv:{}'.format(surv),
                                        'textsrc': 'test'}
                                         for lonp, latp, surv, direction in zip(division_1_segments_LONP,
                                                                     division_1_segments_LATP,
                                                                     division_1.SURVIV,
                                                                     division_1.DIREC)],
                                'layout': {'title': 'End Title', 
                                           'updatemenus': [{'type': 'buttons',
                                                            'buttons': [{'label': 'Play',
                                                                         'method': 'animate',
                                                                         'args': [None]}]}],
                                           'showlegend': False}}]}



iplot(figure)
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>
# <div id="73d88481-0fff-4d45-947e-7a248971b723" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";
#         Plotly.plot(
#             '73d88481-0fff-4d45-947e-7a248971b723',
#             [{"name": "surviv:340000", "marker": {"size": 0}, "mode": "line+marker", "y": [54.6, 54.82], "x": [24.05, 24.8], "line": {"color": "BurlyWood", "width": 0}, "type": "scatter"}, {"name": "surviv:340000", "marker": {"size": 0}, "mode": "line+marker", "y": [54.82, 54.6], "x": [24.8, 25.8], "line": {"color": "BurlyWood", "width": 0}, "type": "scatter"}, {"name": "surviv:340000", "marker": {"size": 0}, "mode": "line+marker", "y": [54.6, 54.85], "x": [25.8, 26.75], "line": {"color": "BurlyWood", "width": 0}, "type": "scatter"}, {"name": "surviv:320000", "marker": {"size": 0}, "mode": "line+marker", "y": [54.85, 55.05], "x": [26.75, 27.499000000000002], "line": {"color": "BurlyWood", "width": 0}, "type": "scatter"}, {"name": "surviv:300000", "marker": {"size": 0}, "mode": "line+marker", "y": [55.05, 55.2], "x": [27.499000000000002, 28.15], "line": {"color": "BurlyWood", "width": 0}, "type": "scatter"}, {"name": "surviv:280000", "marker": {"size": 0}, "mode": "line+marker", "y": [55.2, 55.3], "x": [28.15, 29.0], "line": {"color": "BurlyWood", "width": 0}, "type": "scatter"}, {"name": "surviv:240000", "marker": {"size": 0}, "mode": "line+marker", "y": [55.3, 55.36], "x": [29.0, 29.55], "line": {"color": "BurlyWood", "width": 0}, "type": "scatter"}, {"name": "surviv:210000", "marker": {"size": 0}, "mode": "line+marker", "y": [55.36, 55.405], "x": [29.55, 30.29], "line": {"color": "BurlyWood", "width": 0}, "type": "scatter"}, {"name": "surviv:180000", "marker": {"size": 0}, "mode": "line+marker", "y": [55.405, 55.405], "x": [30.29, 30.5], "line": {"color": "BurlyWood", "width": 0}, "type": "scatter"}, {"name": "surviv:175000", "marker": {"size": 0}, "mode": "line+marker", "y": [55.405, 54.85], "x": [30.5, 32.2], "line": {"color": "BurlyWood", "width": 0}, "type": "scatter"}, {"name": "surviv:145000", "marker": {"size": 0}, "mode": "line+marker", "y": [54.85, 55.4], "x": [32.2, 33.75], "line": {"color": "BurlyWood", "width": 0}, "type": "scatter"}, {"name": "surviv:140000", "marker": {"size": 0}, "mode": "line+marker", "y": [55.4, 56.55], "x": [33.75, 35.05], "line": {"color": "BurlyWood", "width": 0}, "type": "scatter"}, {"name": "surviv:127100", "marker": {"size": 0}, "mode": "line+marker", "y": [56.55, 56.38], "x": [35.05, 36.15], "line": {"color": "BurlyWood", "width": 0}, "type": "scatter"}, {"name": "surviv:100000", "marker": {"size": 0}, "mode": "line+marker", "y": [56.38, 57.1], "x": [36.15, 37.6], "line": {"color": "BurlyWood", "width": 0}, "type": "scatter"}, {"name": "surviv:100000", "marker": {"size": 0}, "mode": "line+marker", "y": [57.1, 56.85], "x": [37.6, 37.75], "line": {"color": "BurlyWood", "width": 0}, "type": "scatter"}, {"name": "surviv:100000", "marker": {"size": 0}, "mode": "line+marker", "y": [56.85, 56.8], "x": [37.75, 37.6], "line": {"color": "black", "width": 0}, "type": "scatter"}, {"name": "surviv:98000", "marker": {"size": 0}, "mode": "line+marker", "y": [56.8, 55.8], "x": [37.6, 37.5], "line": {"color": "black", "width": 0}, "type": "scatter"}, {"name": "surviv:97000", "marker": {"size": 0}, "mode": "line+marker", "y": [55.8, 55.68], "x": [37.5, 37.28], "line": {"color": "black", "width": 0}, "type": "scatter"}, {"name": "surviv:96000", "marker": {"size": 0}, "mode": "line+marker", "y": [55.68, 56.05], "x": [37.28, 35.8], "line": {"color": "black", "width": 0}, "type": "scatter"}, {"name": "surviv:87000", "marker": {"size": 0}, "mode": "line+marker", "y": [56.05, 55.57], "x": [35.8, 34.75], "line": {"color": "black", "width": 0}, "type": "scatter"}, {"name": "surviv:55000", "marker": {"size": 0}, "mode": "line+marker", "y": [55.57, 55.0], "x": [34.75, 33.75], "line": {"color": "black", "width": 0}, "type": "scatter"}, {"name": "surviv:37000", "marker": {"size": 0}, "mode": "line+marker", "y": [55.0, 54.55], "x": [33.75, 32.45], "line": {"color": "black", "width": 0}, "type": "scatter"}, {"name": "surviv:24000", "marker": {"size": 0}, "mode": "line+marker", "y": [54.55, 54.25], "x": [32.45, 30.9] ...
#             {"images": [{"opacity": 1, "sizing": "stretch", "layer": "below", "xref": "x", "yref": "y", "sizex": 15, "sizey": 7, "source": "https://raw.githubusercontent.com/LouisFoucard/minard_viz/master/Minard's_Map.png", "y": 58.25, "x": 23.2}], "showlegend": false, "yaxis": {"range": [51.25, 58.25], "autorange": false}, "xaxis": {"range": [23.1, 38.4], "autorange": false}, "title": "Start Title"},
#             {"linkText": "Export to plot.ly", "showLink": true}
#         ).then(function () {return Plotly.addFrames('73d88481-0fff-4d45-947e-7a248971b723',[{"data": [{"name": "surviv:340000", "textsrc": "test", "marker": {"size": 0}, "mode": "line+marker", "y": [54.6, 54.82], "x": [24.05, 24.8], "line": {"color": "BurlyWood", "width": 0}, "type": "scatter"}, {"name": "surviv:340000", "textsrc": "test", "marker": {"size": 0}, "mode": "line+marker", "y": [54.82, 54.6], "x": [24.8, 25.8], "line": {"color": "BurlyWood", "width": 0}, "type": "scatter"}, {"name": "surviv:340000", "textsrc": "test", "marker": {"size": 0}, "mode": "line+marker", "y": [54.6, 54.85], "x": [25.8, 26.75], "line": {"color": "BurlyWood", "width": 0}, "type": "scatter"}, {"name": "surviv:320000", "textsrc": "test", "marker": {"size": 0}, "mode": "line+marker", "y": [54.85, 55.05], "x": [26.75, 27.499000000000002], "line": {"color": "BurlyWood", "width": 0}, "type": "scatter"}, {"name": "surviv:300000", "textsrc": "test", "marker": {"size": 0}, "mode": "line+marker", "y": [55.05, 55.2], "x": [27.499000000000002, 28.15], "line": {"color": "BurlyWood", "width": 0}, "type": "scatter"}, {"name": "surviv:280000", "textsrc": "test", "marker": {"size": 0}, "mode": "line+marker", "y": [55.2, 55.3], "x": [28.15, 29.0], "line": {"color": "

# %%
from plotly import tools
fig = tools.make_subplots(rows=3, cols=1, specs=[[{}], [{}], [{}]],
                          shared_xaxes=True, shared_yaxes=True,
                          vertical_spacing=0.001)
# Out:
# This is the format of your plot grid:
# [ (1,1) x1,y1 ]
# [ (2,1) x1,y2 ]
# [ (3,1) x1,y3 ]

# %%
fig
# Out:
# {'data': [],
#  'layout': {'xaxis1': {'anchor': 'y3', 'domain': [0.0, 1.0]},
#   'yaxis1': {'anchor': 'free',
#    'domain': [0.6673333333333333, 1.0],
#    'position': 0.0},
#   'yaxis2': {'anchor': 'free',
#    'domain': [0.33366666666666667, 0.6663333333333333],
#    'position': 0.0},
#   'yaxis3': {'anchor': 'x1', 'domain': [0.0, 0.33266666666666667]}}}
